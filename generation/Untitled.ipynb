# %%
root -l pythiaOutput_ttH_sl.root
events->Scan("topIsLeptonic:mtop_lep:mtop_had:mW_lep:mW_had", "", "", 10)
root [0] 
Attaching file pythiaOutput_ttH_sl.root as _file0...
Error in <TNetXNGFile::Open>: [ERROR] Server responded with an error: [3001] Required argument not present

(TFile *) 0x13e765d0
root [1]
# Out:
#   File "/tmp/ipykernel_23598/589062014.py", line 1
#     root -l pythiaOutput_ttH_sl.root
#             ^
# SyntaxError: invalid syntax
